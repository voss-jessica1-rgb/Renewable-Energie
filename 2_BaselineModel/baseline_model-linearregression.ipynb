# %% [markdown]
# # Baseline Model
#
# ## Table of Contents
# 1. [Model Choice](#model-choice)
# 2. [Feature Selection](#feature-selection)
# 3. [Implementation](#implementation)
# 4. [Evaluation](#evaluation)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
# Import your chosen baseline model
# Example: from sklearn.linear_model import LogisticRegression
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Model Choice
#
# [Explain why you've chosen a particular model as the baseline. This could be a simple statistical model or a basic machine learning model. Justify your choice.]

# %% [markdown]
# ## Feature Selection
#
# [Indicate which features from the dataset you will be using for the baseline model, and justify your selection.]

# %%
from math import nan
# Load the dataset
# Replace 'your_dataset.csv' with the path to your actual dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dobersdorf_all_cut.csv', sep=";", decimal=",", header=0)
df_elmshorn = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Elmshorn_PV.csv', sep=";", decimal=",", header=0)


# Feature selection
# Example: Selecting only two features for a simple baseline model
X = df['Sun']
y = df['Produktion(kWH)']
n_y= y/100
n_x= X/100

X1 = df_elmshorn['Sun']
y1 = df_elmshorn['Power Generation [kWh]']
n_y1= y1/100
n_x1= X1/100


# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(n_x, n_y, test_size=0.2, random_state=42)

##elmshorn
X_train1, X_test1, y_train1, y_test1 = train_test_split(n_x1, n_y1, test_size=0.2, random_state=42)
###Dobersdorf
plt.scatter(n_x, n_y)
plt.xlabel('Solar radiation')
plt.ylabel('production(kWh)')
plt.title('Solar radiation vs. production - Dobersdorf ')
plt.show()

##elmshorn
plt.scatter(n_x1, n_y1)
plt.xlabel('Solar radiation')
plt.ylabel('production(kWh)')
plt.title('Solar radiation vs. production - Elmshorn')
plt.show()


X_train = np.nan_to_num(X_train, nan=0.0, posinf=0.0, neginf=0.0)

print("X nan:", np.isnan(X_train).any())
print("y nan:", np.isnan(y_train).any())
print("X inf:", np.isinf(X_train).any())
print("y inf:", np.isinf(y_train).any())

X_train1 = np.nan_to_num(X_train1, nan=0.0, posinf=0.0, neginf=0.0)
print("X nan:", np.isnan(X_train1).any())
print("y nan:", np.isnan(y_train1).any())
print("X inf:", np.isinf(X_train1).any())
print("y inf:", np.isinf(y_train1).any())
# Out:
# X nan: False
# y nan: False
# X inf: False
# y inf: False
# X nan: False
# y nan: False
# X inf: False
# y inf: False

# %% [markdown]
# ## Implementation
#
# [Implement your baseline model here.]

# %%
from tensorflow import keras



model = keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(1)
])


# TODO Compile the model
model.compile(
loss= keras.losses.MeanSquaredError(),
optimizer= keras.optimizers.Adam(learning_rate=0.001),
metrics=["mae"]
               )


model.fit(X_train,y_train,batch_size=16, epochs=50)


###for Elmshorn



model1 = keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(1)
])


# TODO Compile the model
model1.compile(
loss= keras.losses.MeanSquaredError(),
optimizer= keras.optimizers.Adam(learning_rate=0.001),
metrics=["mae"]
               )


model1.fit(X_train1,y_train1,batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1023 - mae: 0.2450
# Epoch 2/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1889
# Epoch 3/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0415 - mae: 0.1801
# Epoch 4/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0390 - mae: 0.1728
# Epoch 5/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0397 - mae: 0.1754
# Epoch 6/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - mae: 0.1709
# Epoch 7/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0335 - mae: 0.1618
# Epoch 8/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0313 - mae: 0.1555
# Epoch 9/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0288 - mae: 0.1498
# Epoch 10/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0254 - mae: 0.1391
# Epoch 11/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - mae: 0.1354
# Epoch 12/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - mae: 0.1292
# Epoch 13/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0223 - mae: 0.1291
# Epoch 14/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - mae: 0.1167
# Epoch 15/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - mae: 0.1209
# Epoch 16/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - mae: 0.1141
# Epoch 17/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - mae: 0.1140
# Epoch 18/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - mae: 0.1073
# Epoch 19/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mae: 0.1107
# Epoch 20/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171 - mae: 0.1060
# Epoch 21/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - mae: 0.1050
# Epoch 22/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - mae: 0.1121
# Epoch 23/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197 - mae: 0.1109
# Epoch 24/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mae: 0.1076
# Epoch 25/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - mae: 0.1065
# Epoch 26/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - mae: 0.1109
# Epoch 27/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mae: 0.1085
# Epoch 28/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0199 - mae: 0.1128
# Epoch 29/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mae: 0.1092
# Epoch 30/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - mae: 0.1063
# Epoch 31/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - mae: 0.1037
# Epoch 32/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - mae: 0.1027
# Epoch 33/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - mae: 0.1049
# Epoch 34/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171 - mae: 0.1045
# Epoch 35/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - mae: 0.1089
# Epoch 36/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171 - mae: 0.1056
# Epoch 37/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mae: 0.1072
# Epoch 38/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - mae: 0.1021
# Epoch 39/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - mae: 0.1093
# Epoch 40/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - mae: 0.1033
# Epoch 41/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - mae: 0.1060
# Epoch 42/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - mae: 0.1060
# Epoch 43/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - mae: 0.1068
# Epoch 44/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - mae: 0.1024
# Epoch 45/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - mae: 0.1035
# Epoch 46/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mae: 0.1060
# Epoch 47/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - mae: 0.1049
# Epoch 48/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - mae: 0.1001
# Epoch 49/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - mae: 0.1018
# Epoch 50/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172 - mae: 0.1068
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0371 - mae: 0.1481
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - mae: 0.1084
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128 - mae: 0.0972
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - mae: 0.0954
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114 - mae: 0.0933
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111 - mae: 0.0919
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - mae: 0.0888
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - mae: 0.0841
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - mae: 0.0785
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - mae: 0.0742
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - mae: 0.0717
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - mae: 0.0700
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mae: 0.0629
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mae: 0.0620
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0571
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0549
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0530
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0526
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0493
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0493
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0461
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0472
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0465
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0449
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0453
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0461
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0462
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - mae: 0.0437
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0450
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0456
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0447
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0446
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0455
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0438
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0423
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0450
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0465
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mae: 0.0440
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0474
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - mae: 0.0461
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0449
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0448
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0451
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0420
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0443
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0460
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0463
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0439
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0475
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0462

# %% [markdown]
# ## Evaluation
#
# [Clearly state what metrics you will use to evaluate the model's performance. These metrics will serve as a starting point for evaluating more complex models later on.]

# %%
# Evaluate the baseline model

model.evaluate(X_train,y_train)

# TODO Make predictions
forecast = model.predict(X_test)

# TODO Plot real vs predicted prices (hint: you can use the plotting code from above as a start)
plt.scatter(X_test, y_test,color="blue",label="actual production")
plt.scatter(X_test,forecast, color="red", label="forecasted procuction")
plt.xlabel('solar radiation')
plt.ylabel('production')
plt.title('real vs forecasted solar production in Dobersdorf')
plt.legend()
plt.show()


###for Elmshorn
# Evaluate the baseline model

model1.evaluate(X_train1,y_train1)


forecast1 = model1.predict(X_test1)

plt.scatter(X_test1, y_test1,color="blue",label="actual production")
plt.scatter(X_test1,forecast1, color="red", label="forecasted procuction")
plt.xlabel('solar radiation')
plt.ylabel('production')
plt.title('real vs forecasted solar production in Elmshorn')
plt.legend()
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - mae: 0.1051
# WARNING:tensorflow:5 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7db3b38e60c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0452
# WARNING:tensorflow:5 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7db3b1ef8400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
